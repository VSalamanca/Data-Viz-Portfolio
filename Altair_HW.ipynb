# %%
import altair as alt
import pandas as pd

# %%
police_shooting = pd.read_csv('https://raw.githubusercontent.com/VSalamanca/Data-Viz-with-Python/master/Fatal_Police_Shootings.csv')
police_shooting
# Out:
#         id                   name  ...         flee body_camera
# 0        3             Tim Elliot  ...  Not fleeing       False
# 1        4       Lewis Lee Lembke  ...  Not fleeing       False
# 2        5     John Paul Quintero  ...  Not fleeing       False
# 3        8        Matthew Hoffman  ...  Not fleeing       False
# 4        9      Michael Rodriguez  ...  Not fleeing       False
# ...    ...                    ...  ...          ...         ...
# 1846  2064          Michael Giles  ...         Foot       False
# 1847  2065                  TK TK  ...  Not fleeing       False
# 1848  2066    Ivory C. Pantallion  ...          Car       False
# 1849  2067  Frank Nathaniel Clark  ...  Not fleeing       False
# 1850  2068           Tai Upchurch  ...  Not fleeing       False
#
# [1851 rows x 14 columns]

# %%
new_data = police_shooting[['date', 'name','age', 'gender', 'state', 'race', 'signs_of_mental_illness']]

state_shooting = pd.DataFrame(new_data['state'].value_counts())
state_shooting['Percentage'] = state_shooting['state']/state_shooting['state'].sum()
state_shooting.reset_index(level=0, inplace=True)
state_shooting_1 = state_shooting.rename(columns={'index': 'State', 'state': 'Shootings'})

state_shooting_1
# Out:
#    State  Shootings  Percentage
# 0     CA        313    0.169098
# 1     TX        172    0.092923
# 2     FL        111    0.059968
# 3     AZ         87    0.047002
# 4     CO         60    0.032415
# 5     OK         55    0.029714
# 6     OH         53    0.028633
# 7     GA         53    0.028633
# 8     NC         51    0.027553
# 9     IL         43    0.023231
# 10    LA         43    0.023231
# 11    MO         41    0.022150
# 12    NM         40    0.021610
# 13    TN         40    0.021610
# 14    WA         39    0.021070
# 15    AL         39    0.021070
# 16    NY         36    0.019449
# 17    PA         35    0.018909
# 18    VA         35    0.018909
# 19    SC         34    0.018368
# 20    KY         33    0.017828
# 21    NV         32    0.017288
# 22    IN         28    0.015127
# 23    MI         28    0.015127
# 24    WI         28    0.015127
# 25    NJ         27    0.014587
# 26    MD         27    0.014587
# 27    OR         26    0.014046
# ...

# %%
source = state_shooting_1

alt.Chart(source).mark_bar(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    x='State',
    y='Shootings',
    color='Percentage'
).properties(
    title="# of Shootings in Each State")
# Out:
# alt.Chart(...)

# %%
source = new_data

alt.Chart(source).mark_bar(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    x='signs_of_mental_illness',
    y='race',
    color='race'
).properties(
    title="# of Shootings in Each State")
# Out:
# alt.Chart(...)
